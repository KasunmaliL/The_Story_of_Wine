# %%
# !pip install transformers
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 645.7 kB/s eta 0:00:15
#    --- ------------------------------------ 0.8/10.0 MB 685.3 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/10.0 MB 685.3 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.0/10.0 MB 709.1 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.3/10.0 MB 754.4 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/10.0 MB 754.4 kB/s eta 0:00:12
#    ------ --------------------------------- 1.6/10.0 MB 777.0 kB/s eta 0:00:11
# ...

# %%
# Import libraries
import pandas as pd
from transformers import pipeline
import matplotlib.pyplot as plt

# %%
#Load the wine_reviews dataset
file_path = 'wine_reviews.csv'  # Update the path to your file if needed
w_review = pd.read_csv(file_path)

# %%
print(w_review.head())
# Out:
#                                               review
# 0  Easily the best Sauvignon Blanc I've had to da...
# 1                      Excellent, Mockingbird Inn?\n
# 2  Absolutely incredible. One of the best sauvign...
# 3                   Reported in nytimes. Did not try
# 4  Great. Much different than other Sauv Blancs s...

# %%
# !pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.8/390.3 MB 2.4 MB/s eta 0:02:43
#    ---------------------------------------- 1.6/390.3 MB 3.0 MB/s eta 0:02:10
#    ---------------------------------------- 2.4/390.3 MB 3.0 MB/s eta 0:02:08
#    ---------------------------------------- 2.6/390.3 MB 3.1 MB/s eta 0:02:04
#    ---------------------------------------- 2.6/390.3 MB 3.1 MB/s eta 0:02:04
#    ---------------------------------------- 2.6/390.3 MB 3.1 MB/s eta 0:02:04
#    ---------------------------------------- 4.7/390.3 MB 2.9 MB/s eta 0:02:13
#     --------------------------------------- 5.0/390.3 MB 2.7 MB/s eta 0:02:25
#     --------------------------------------- 5.8/390.3 MB 2.8 MB/s eta 0:02:20
# ...
